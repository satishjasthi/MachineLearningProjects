# %%
import pandas as pd
import sqlite3

# %%
con = sqlite3.connect('Edited.sqlite')
data = pd.read_sql_query('select * from Users_table',con,index_col='UserID')

# %%
data.drop(['index','q2'],axis=1)
# Out:
#         q1                        q3         q4  q5   q6 q7              q8  \
# UserID
# 1       37             United States   Illinois  -1   No  1            6-25
# 2       44             United States    Indiana  -1   No  0  More than 1000
# 3       32                    Canada         -1  -1   No  0            6-25
# 4       31            United Kingdom         -1  -1  Yes  1          26-100
# 5       31             United States      Texas  -1   No  0         100-500
# ...     ..                       ...        ...  ..  ... ..             ...
# 4214    27                     India         -1   0   No  0  More than 1000
# 4215    48  United States of America  Louisiana   1   No  0              -1
# 4216    50                     India         -1   1   No  0              -1
# 4217    30                     India         -1   0   No  0  More than 1000
# 4218    24  United States of America     Oregon   0  Yes  1  More than 1000
#
# ...
